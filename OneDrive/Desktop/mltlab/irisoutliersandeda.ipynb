# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
#differnce between df vs series?
#ans -> Series can only contain single list with index, whereas dataframe can be made of more than one series or we can say that a dataframe is a collection of series that can be used to analyse the data. 



df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
#how to rename columns?
#create a new dataframe from existing dataframe
df4=df
df4.rename(columns={'SepalLengthCm':'slcm'},inplace=True)
df4
# Out:
#       Id  slcm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0      1   5.1           3.5            1.4           0.2     Iris-setosa
# 1      2   4.9           3.0            1.4           0.2     Iris-setosa
# 2      3   4.7           3.2            1.3           0.2     Iris-setosa
# 3      4   4.6           3.1            1.5           0.2     Iris-setosa
# 4      5   5.0           3.6            1.4           0.2     Iris-setosa
# ..   ...   ...           ...            ...           ...             ...
# 145  146   6.7           3.0            5.2           2.3  Iris-virginica
# 146  147   6.3           2.5            5.0           1.9  Iris-virginica
# 147  148   6.5           3.0            5.2           2.0  Iris-virginica
# 148  149   6.2           3.4            5.4           2.3  Iris-virginica
# 149  150   5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style("whitegrid")
sns.FacetGrid(df,hue="Species",height=4).map(plt.scatter,'SepalLengthCm','SepalWidthCm').add_legend()

# %%
plt.figure(figsize=(7,7))
plt.scatter(df['PetalLengthCm'],df['PetalWidthCm'])
plt.xlabel("PETALLENGTHCM")
plt.ylabel("PETALWIDTHCM")
# Out:
# Text(0, 0.5, 'PETALWIDTHCM')

# %%
df1=df.drop(['Id'],axis=1)

# %%
df1.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#how to drop multiple columns?
df3=df.drop(['Id','SepalLengthCm'],axis=1)
df3.head()
# Out:
#    SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0           3.5            1.4           0.2  Iris-setosa
# 1           3.0            1.4           0.2  Iris-setosa
# 2           3.2            1.3           0.2  Iris-setosa
# 3           3.1            1.5           0.2  Iris-setosa
# 4           3.6            1.4           0.2  Iris-setosa

# %%
df1.corr()
# Out:
#                SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# SepalLengthCm       1.000000     -0.109369       0.871754      0.817954
# SepalWidthCm       -0.109369      1.000000      -0.420516     -0.356544
# PetalLengthCm       0.871754     -0.420516       1.000000      0.962757
# PetalWidthCm        0.817954     -0.356544       0.962757      1.000000

# %%
sns.heatmap(df1.corr(),annot=True)

# %%
sns.pairplot(df1)

# %%
#how to detect outliers using box plot?
df1.boxplot(figsize=(5,5),fontsize='8')

# %%
#difference b/w loc and iloc
df1.iloc[1:2]
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1            4.9           3.0            1.4           0.2  Iris-setosa

# %%
df1.loc[1:2]
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa

# %%
#explore use of groupby function
df5=df1.groupby('SepalLengthCm')
df5.first()
# Out:
#                SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# SepalLengthCm
# 4.3                     3.0            1.1           0.1      Iris-setosa
# 4.4                     2.9            1.4           0.2      Iris-setosa
# 4.5                     2.3            1.3           0.3      Iris-setosa
# 4.6                     3.1            1.5           0.2      Iris-setosa
# 4.7                     3.2            1.3           0.2      Iris-setosa
# 4.8                     3.4            1.6           0.2      Iris-setosa
# 4.9                     3.0            1.4           0.2      Iris-setosa
# 5.0                     3.6            1.4           0.2      Iris-setosa
# 5.1                     3.5            1.4           0.2      Iris-setosa
# 5.2                     3.5            1.5           0.2      Iris-setosa
# 5.3                     3.7            1.5           0.2      Iris-setosa
# ...

# %%
#what is quartile 25,50,75?
def outlier(arr1):
  q1 = np.quantile(arr1, 0.25)
  q3 = np.quantile(arr1, 0.75)
  med = np.median(arr1)
  # finding the iqr region
  iqr = q3-q1
  # finding upper and lower whiskers
  upper_bound = q3+(1.5*iqr)
  lower_bound = q1-(1.5*iqr)
  outliers=[]
  for i in range(len(arr1)):
    if arr1[i]<=lower_bound or arr1[i]>=upper_bound:
      outliers.append(arr1[i])
  return outliers

# %%
outlier(df['SepalLengthCm'])
# Out:
# []

# %%
outlier(df['SepalWidthCm'])
# Out:
# [4.4, 4.1, 4.2, 2.0]

# %%
outlier(df['PetalWidthCm'])
# Out:
# []

# %%
outlier(df['PetalLengthCm'])
# Out:
# []
